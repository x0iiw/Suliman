# %% [markdown]
# # Exercise: Object Counting Using YOLO with a Line in the Middle of the Frame
# In this exercise, you will implement an object counting system using YOLOv8. You will process a video and count the number of objects crossing a line drawn in the middle of the frame. Follow the steps below to complete the exercise.
#
# ## Objective:
# The goal is to load a video, detect objects, count them as they cross a line, and save the processed video with the results.
#
# ## Steps to Complete:

# %% [markdown]
# ### Step 1: Install the Required Libraries
# - Install the `ultralytics` library using pip to work with YOLOv8.
# - Also ensure you have OpenCV installed for video processing.
#
# _Hint_: You can install a library using the `!pip install` command in a code cell.

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.1/871.1 kB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 24.0 MB/s eta 0:00:00

# %% [markdown]
# ### Step 2: Import the Libraries
# - Import the necessary libraries, including `cv2` from OpenCV and `YOLO` from `ultralytics`.
# - You will also need to import any other required libraries for object counting and video handling.

# %%
import cv2
from ultralytics import YOLO, solutions

# %% [markdown]
# ### Step 3: Load the YOLO Model
# - Load the pre-trained YOLOv8 model (e.g., `yolov8n.pt`) to perform object detection and tracking.

# %%
model = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 287MB/s]

# %% [markdown]
# ### Step 4: Capture and Process the Video
# - Use OpenCV to capture the video from a specified file path.
# - Ensure the video file opens successfully and retrieve the video properties (such as width, height, and frames per second).

# %%
cap = cv2.VideoCapture('/content/Motion_Detection_Test.mp4')
assert cap.isOpened(), 'Error reading video file'
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# %% [markdown]
# ### Step 5: Define the Line in the Middle of the Frame
# - Calculate the vertical middle of the frame using the height of the video.
# - Define two points to represent a horizontal line in the middle of the frame.

# %%
mid_y = h // 2
line_points = [(20, mid_y), (w - 20, mid_y)]

# %% [markdown]
# ### Step 6: Set Up the Video Writer
# - Create a video writer object to save the output video in MP4 format.
# - Choose the appropriate codec and ensure the output video properties match the input video.

# %%
video_writer = cv2.VideoWriter('object_counting_output.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))

# %% [markdown]
# ### Step 7: Initialize the Object Counter
# - Use the `solutions.ObjectCounter` class to handle the object counting logic.
# - Pass in the necessary parameters, including the line points, object names, and any visual settings.

# %%
counter = solutions.ObjectCounter(
    view_img=True,
    reg_pts=line_points,
    names=model.names,
    draw_tracks=True,
    line_thickness=2,
)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Line Counter Initiated.

# %% [markdown]
# ### Step 8: Process the Video Frames
# - Loop through each frame of the video using OpenCV.
# - Apply YOLOv8 to detect and track objects in each frame.
# - Use the object counter to count the number of objects crossing the line.
# - Write each processed frame to the output video.

# %%
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print('Video frame is empty or video processing has been successfully completed.')
        break

    # Perform object tracking
    tracks = model.track(im0, persist=True, show=False)

    # Count objects and draw the middle line
    im0 = counter.start_counting(im0, tracks)
    video_writer.write(im0)
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Collecting lapx>=0.5.2
#   Downloading lapx-0.5.10.post1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from lapx>=0.5.2) (1.25.2)
# Downloading lapx-0.5.10.post1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.2 MB/s eta 0:00:00
# Installing collected packages: lapx
# Successfully installed lapx-0.5.10.post1
#
# requirements: AutoUpdate success ✅ 5.2s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# 0: 416x640 1 bird, 1 clock, 375.9ms
# Speed: 35.7ms preprocess, 375.9ms inference, 30.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 clock, 162.3ms
# Speed: 4.6ms preprocess, 162.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 clock, 158.3ms
# Speed: 5.7ms preprocess, 158.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 clock, 153.9ms
# Speed: 6.9ms preprocess, 153.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 airplane, 158.6ms
# Speed: 5.9ms preprocess, 158.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 201.6ms
# Speed: 7.4ms preprocess, 201.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 158.7ms
# Speed: 6.2ms preprocess, 158.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 164.6ms
# Speed: 6.2ms preprocess, 164.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 161.5ms
# Speed: 6.1ms preprocess, 161.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 171.1ms
# Speed: 8.3ms preprocess, 171.1ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 156.3ms
# Speed: 4.2ms preprocess, 156.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 154.5ms
# Speed: 4.8ms preprocess, 154.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 161.5ms
# Speed: 6.9ms preprocess, 161.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 153.4ms
# Speed: 5.7ms preprocess, 153.4ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 172.5ms
# Speed: 6.0ms preprocess, 172.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 153.4ms
# Speed: 5.9ms preprocess, 153.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 163.3ms
# Speed: 6.4ms preprocess, 163.3ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 153.6ms
# Speed: 6.0ms preprocess, 153.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 157.8ms
# Speed: 6.4ms preprocess, 157.8ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 168.6ms
# Speed: 6.5ms preprocess, 168.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 203.2ms
# Speed: 5.6ms preprocess, 203.2ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 233.9ms
# Speed: 8.1ms preprocess, 233.9ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 275.3ms
# Speed: 5.9ms preprocess, 275.3ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 239.2ms
# Speed: 5.6ms preprocess, 239.2ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 234.9ms
# Speed: 6.5ms preprocess, 234.9ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 239.7ms
# Speed: 6.2ms preprocess, 239.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 241.6ms
# Speed: 7.0ms preprocess, 241.6ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 258.9ms
# Speed: 5.7ms preprocess, 258.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 270.5ms
# Speed: 6.4ms preprocess, 270.5ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 250.4ms
# Speed: 8.5ms preprocess, 250.4ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 202.8ms
# Speed: 6.2ms preprocess, 202.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 157.7ms
# Speed: 6.7ms preprocess, 157.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 174.5ms
# Speed: 5.4ms preprocess, 174.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 149.3ms
# Speed: 6.4ms preprocess, 149.3ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 160.2ms
# Speed: 5.2ms preprocess, 160.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 156.4ms
# Speed: 5.0ms preprocess, 156.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 157.2ms
# Speed: 6.6ms preprocess, 157.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car,
ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 1 truck, 167.4ms
# Speed: 6.3ms preprocess, 167.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 1 truck, 170.5ms
# Speed: 6.3ms preprocess, 170.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 1 truck, 191.8ms
# Speed: 6.4ms preprocess, 191.8ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 1 truck, 229.7ms
# Speed: 7.0ms preprocess, 229.7ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 1 truck, 248.4ms
# Speed: 10.2ms preprocess, 248.4ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 1 truck, 247.8ms
# Speed: 7.4ms preprocess, 247.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# ...
# Speed: 6.8ms preprocess, 236.8ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 238.2ms
# Speed: 6.9ms preprocess, 238.2ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 238.8ms
# Speed: 5.9ms preprocess, 238.8ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 238.6ms
# Speed: 6.1ms preprocess, 238.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 238.6ms
# Speed: 6.5ms preprocess, 238.6ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 268.6ms
# Speed: 6.0ms preprocess, 268.6ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 239.5ms
# Speed: 6.1ms preprocess, 239.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 243.9ms
# Speed: 8.1ms preprocess, 243.9ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 248.7ms
# Speed: 5.9ms preprocess, 248.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 airplane, 172.9ms
# Speed: 6.3ms preprocess, 172.9ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 168.8ms
# Speed: 6.2ms preprocess, 168.8ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 161.5ms
# Speed: 5.9ms preprocess, 161.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 155.7ms
# Speed: 5.8ms preprocess, 155.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 170.0ms
# Speed: 6.2ms preprocess, 170.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 162.4ms
# Speed: 6.6ms preprocess, 162.4ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 178.1ms
# Speed: 6.5ms preprocess, 178.1ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 161.2ms
# Speed: 6.8ms preprocess, 161.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 174.1ms
# Speed: 6.7ms preprocess, 174.1ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 159.5ms
# Speed: 6.5ms preprocess, 159.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 168.4ms
# Speed: 7.7ms preprocess, 168.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 156.6ms
# Speed: 6.0ms preprocess, 156.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 173.6ms
# Speed: 7.0ms preprocess, 173.6ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 166.2ms
# Speed: 6.0ms preprocess, 166.2ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 166.0ms
# Speed: 6.8ms preprocess, 166.0ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 153.2ms
# Speed: 6.7ms preprocess, 153.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 155.7ms
# Speed: 5.6ms preprocess, 155.7ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 166.7ms
# Speed: 6.6ms preprocess, 166.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 156.2ms
# Speed: 6.2ms preprocess, 156.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 164.1ms
# Speed: 6.0ms preprocess, 164.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 154.5ms
# Speed: 6.3ms preprocess, 154.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 158.7ms
# Speed: 5.9ms preprocess, 158.7ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 155.2ms
# Speed: 6.7ms preprocess, 155.2ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 165.6ms
# Speed: 5.8ms preprocess, 165.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 152.7ms
# Speed: 5.5ms preprocess, 152.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 193.6ms
# Speed: 6.8ms preprocess, 193.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 162.4ms
# Speed: 6.4ms preprocess, 162.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 157.8ms
# Speed: 8.6ms preprocess, 157.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 164.7ms
# Speed: 8.3ms preprocess, 164.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 train, 158.2ms
# Speed: 6.7ms preprocess, 158.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 train, 151.2ms
# Speed: 6.0ms preprocess, 151.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 train, 159.1ms
# Speed: 5.9ms preprocess, 159.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 train, 171.3ms
# Speed: 7.5ms preprocess, 171.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 148.6ms
# Speed: 6.2ms preprocess, 148.6ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 154.3ms
# Speed: 6.4ms preprocess, 154.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 train, 1 truck, 168.3ms
# Speed: 9.1ms preprocess, 168.3ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 bus, 1 train, 155.1ms
# Speed: 7.1ms preprocess, 155.1ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 171.7ms
# Speed: 6.3ms preprocess, 171.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 bus, 1 train, 165.6ms
# Speed: 6.6ms preprocess, 165.6ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 train, 165.4ms
# Speed: 6.5ms preprocess, 165.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 train, 1 truck, 174.9ms
# Speed: 7.7ms preprocess, 174.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 trucks, 168.8ms
# Speed: 6.1ms preprocess, 168.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 151.8ms
# Speed: 5.6ms preprocess, 151.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 trucks, 162.5ms
# Speed: 6.5ms preprocess, 162.5ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 246.2ms
# Speed: 8.6ms preprocess, 246.2ms inference, 4.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 238.0ms
# Speed: 6.0ms preprocess, 238.0ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 232.8ms
# Speed: 10.1ms preprocess, 232.8ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 trucks, 217.9ms
# Speed: 6.2ms preprocess, 217.9ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 bus, 235.2ms
# Speed: 9.1ms preprocess, 235.2ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 248.9ms
# Speed: 7.1ms preprocess, 248.9ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 237.8ms
# Speed: 6.9ms preprocess, 237.8ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 trucks, 272.3ms
# Speed: 7.3ms preprocess, 272.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 trucks, 245.1ms
# Speed: 8.0ms preprocess, 245.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 242.0ms
# Speed: 7.3ms preprocess, 242.0ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 236.0ms
# Speed: 7.0ms preprocess, 236.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 158.9ms
# Speed: 6.4ms preprocess, 158.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 trucks, 154.8ms
# Speed: 7.3ms preprocess, 154.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 164.2ms
# Speed: 6.6ms preprocess, 164.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 158.6ms
# Speed: 6.2ms preprocess, 158.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 train, 1 truck, 168.6ms
# Speed: 12.5ms preprocess, 168.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 155.8ms
# Speed: 7.7ms preprocess, 155.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 158.3ms
# Speed: 6.9ms preprocess, 158.3ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 trucks, 171.0ms
# Speed: 6.2ms preprocess, 171.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 180.1ms
# Speed: 6.2ms preprocess, 180.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 154.8ms
# Speed: 5.8ms preprocess, 154.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 160.0ms
# Speed: 6.5ms preprocess, 160.0ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 158.7ms
# Speed: 6.1ms preprocess, 158.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 152.4ms
# Speed: 6.1ms preprocess, 152.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 187.1ms
# Speed: 5.8ms preprocess, 187.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 156.3ms
# Speed: 6.9ms preprocess, 156.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 156.6ms
# Speed: 6.0ms preprocess, 156.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 161.9ms
# Speed: 6.1ms preprocess, 161.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 truck, 173.6ms
# Speed: 5.7ms preprocess, 173.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 158.0ms
# Speed: 6.2ms preprocess, 158.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 152.9ms
# Speed: 6.9ms preprocess, 152.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 159.5ms
# Speed: 7.8ms preprocess, 159.5ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 156.5ms
# Speed: 5.9ms preprocess, 156.5ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 167.4ms
# Speed: 5.9ms preprocess, 167.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 157.8ms
# Speed: 5.6ms preprocess, 157.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 158.5ms
# Speed: 7.3ms preprocess, 158.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 154.6ms
# Speed: 6.5ms preprocess, 154.6ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 157.2ms
# Speed: 6.9ms preprocess, 157.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 165.6ms
# Speed: 4.9ms preprocess, 165.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 157.4ms
# Speed: 5.3ms preprocess, 157.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 163.3ms
# Speed: 6.8ms preprocess, 163.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 156.6ms
# Speed: 6.8ms preprocess, 156.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 171.5ms
# Speed: 6.5ms preprocess, 171.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 164.2ms
# Speed: 5.8ms preprocess, 164.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 160.9ms
# Speed: 6.1ms preprocess, 160.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 156.7ms
# Speed: 6.3ms preprocess, 156.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 162.3ms
# Speed: 7.3ms preprocess, 162.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 179.1ms
# Speed: 6.1ms preprocess, 179.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 176.7ms
# Speed: 6.2ms preprocess, 176.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 157.8ms
# Speed: 7.0ms preprocess, 157.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 158.7ms
# Speed: 6.4ms preprocess, 158.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 154.6ms
# Speed: 6.0ms preprocess, 154.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 164.2ms
# Speed: 6.9ms preprocess, 164.2ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 156.0ms
# Speed: 6.3ms preprocess, 156.0ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 162.6ms
# Speed: 6.4ms preprocess, 162.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 155.8ms
# Speed: 6.3ms preprocess, 155.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 149.3ms
# Speed: 6.1ms preprocess, 149.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 168.2ms
# Speed: 6.9ms preprocess, 168.2ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 239.4ms
# Speed: 7.7ms preprocess, 239.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 245.0ms
# Speed: 6.1ms preprocess, 245.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 231.2ms
# Speed: 6.6ms preprocess, 231.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 236.3ms
# Speed: 6.7ms preprocess, 236.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 239.6ms
# Speed: 6.1ms preprocess, 239.6ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 237.0ms
# Speed: 7.5ms preprocess, 237.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 239.0ms
# Speed: 8.9ms preprocess, 239.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 239.2ms
# Speed: 6.6ms preprocess, 239.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 251.9ms
# Speed: 6.7ms preprocess, 251.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 250.0ms
# Speed: 6.4ms preprocess, 250.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# Video frame is empty or video processing has been successfully completed.

# %% [markdown]
# ### Step 9: Release Resources
# - Once the video processing is complete, release the video capture and writer objects.
# - Close any OpenCV windows that were opened during the process.

# %%
cap.release()
video_writer.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Conclusion
# By completing this exercise, you will have implemented an object counting system using YOLOv8 and OpenCV. The final output will be a video with objects counted as they cross a line in the middle of the frame.
